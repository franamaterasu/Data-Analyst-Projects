# %% [markdown]
# # ![Steam](https://www.vortez.net/contentteller.php?ct=news&action=file&id=18653)
#
# ## Steam games analysis
#
# Este proyecto tiene como objetivo realizar un análisis exhaustivo de un conjunto de datos de juegos de la plataforma Steam.
#
# El proceso comienza con la limpieza y transformación de los datos para asegurar su calidad y consistencia, abordando aspectos como la eliminación de datos faltantes y la corrección de errores.
#
# Posteriormente, se llevará a cabo una serie de análisis y filtrados para extraer información relevante sobre los juegos, como sus precios, valoraciones y descuentos.
#
# El objetivo final es obtener conclusiones útiles que puedan proporcionar una visión detallada del mercado de juegos en Steam y apoyar decisiones informadas sobre tendencias y preferencias de los usuarios.

# %% [markdown]
# ---
# #### 1. Carga y exploración inicial
# ---

# %%
import pandas as pd

filepath = './data/steam_store_data_2024.csv'

df = pd.read_csv(filepath)

# %%
# Obtenemos un resumen del DataFrame con las primeas 5 filas

df.head()
# Out:
#                                                title  \
# 0                      Ori and the Will of the Wisps
# 1  Flashing Lights - Police, Firefighting, Emerge...
# 2                                         Thronefall
# 3  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...
# 4                                            UNDYING
#
#                                          description   price salePercentage  \
# 0  Play the critically acclaimed masterpiece. Emb...   $9.89           -67%
# 1  Play solo or in up to 10-player multiplayer co...   $8.49           -66%
# 2  A minimalist game about building and defending...   $5.24           -25%
# 3  The Definitive Edition includes the critically...  $23.99           -40%
# 4  As Anling’s zombie infection sets in, her days...  $13.99           -30%
#
#              recentReviews               allReviews
# 0  Overwhelmingly Positive  Overwhelmingly Positive
# 1            Very Positive            Very Positive
# 2  Overwhelmingly Positive  Overwhelmingly Positive
# 3            Very Positive            Very Positive
# 4          Mostly Positive          Mostly Positive

# %%
# Obtenemos información básica sobre el DataFrame

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           86 non-null     object
#  1   description     82 non-null     object
#  2   price           61 non-null     object
#  3   salePercentage  59 non-null     object
#  4   recentReviews   57 non-null     object
#  5   allReviews      57 non-null     object
# dtypes: object(6)
# memory usage: 4.2+ KB

# %%
# Obtenemos el nombre de todas las columnas

df.columns
# Out:
# Index(['title', 'description', 'price', 'salePercentage', 'recentReviews',
#        'allReviews'],
#       dtype='object')

# %%
# Obtenemos el tipo de dato de cada columna

df.dtypes
# Out:
# title             object
# description       object
# price             object
# salePercentage    object
# recentReviews     object
# allReviews        object
# dtype: object

# %%
# Obtenemos un resumen estadístico del DataFrame

df.describe()
# Out:
#                                 title  \
# count                              86
# unique                             75
# top     Ori and the Will of the Wisps
# freq                                2
#
#                                               description   price  \
# count                                                  82      61
# unique                                                 71      34
# top     Play the critically acclaimed masterpiece. Emb...  $23.99
# freq                                                    2       6
#
#        salePercentage  recentReviews     allReviews
# count              59             57             57
# unique             17              5              5
# top              -40%  Very Positive  Very Positive
# freq               10             40             40

# %%
# Obtenemos la cantidad de filas y columnas que tiene el DataFrame

df.shape
# Out:
# (86, 6)

# %% [markdown]
# ---
# #### 2. Limpieza de datos y exportación a un nuevo CSV
# ---

# %% [markdown]
# ##### Comprueba si existem registros con datos nulos y modificalos con la mejor opción

# %%
df.isnull().sum()
# Out:
# title              0
# description        4
# price             25
# salePercentage    27
# recentReviews     29
# allReviews        29
# dtype: int64

# %% [markdown]
# Modificamos los nulos de __'description'__:

# %%
# Cambiamos los datos nulos de 'description' por un string

df['description'] = df['description'].fillna('Desconocida')

df[df['description'] == 'Desconocida']
# Out:
#                                                title  description   price  \
# 13                        Poppy Playtime - Chapter 3  Desconocida   $9.89
# 20  HELLDIVERS™ 2 - Upgrade to Super Citizen Edition  Desconocida  $59.99
# 68                          Halo Infinite (Campaign)  Desconocida  $23.99
# 76                Destiny 2: Lightfall + Annual Pass  Desconocida  $33.00
#
#    salePercentage    recentReviews       allReviews
# 13           -34%    Very Positive    Very Positive
# 20            NaN              NaN              NaN
# 68           -60%            Mixed            Mixed
# 76           -67%  Mostly Negative  Mostly Negative

# %% [markdown]
# Modificamos los nulos de __'price'__:

# %%
# Eliminamos el símbolo "$"
df['price'] = df['price'].str.replace("$", "")

# Cambiamos el tipo de dato a tipo 'float'
df["price"] = df["price"].astype(float)

# Calculamos el valor medio de la columna
valor_medio_de_precios = df['price'].median()

# Asignamos el valor medio a los registros con el valor nulo
df['price'] = df['price'].fillna(valor_medio_de_precios)

# %% [markdown]
# Modificamos los nulos de __'salesPercentage'__:

# %%
# Eliminamos el símbolo '%'
df["salePercentage"] = df["salePercentage"].str.replace("%", "")

# Cambiamos el tipo de dato a tipo 'int'ArithmeticError
df['salePercentage'] = df['salePercentage'].astype(float)

# Calculamos el valor moda de la columna
valor_moda_de_salePercentage = df['salePercentage'].mode()[0]

# Asignamos el valor moda a los registros con el valor nulo
df["salePercentage"] = df["salePercentage"].fillna(valor_moda_de_salePercentage)

# %% [markdown]
# Modificamos los nulos de __'recentReviews'__ y __'allReviews'__:

# %%
df["recentReviews"] = df["recentReviews"].fillna("Desconocida")

df[df["recentReviews"] == "Desconocida"]
# Out:
#                                                 title  \
# 20   HELLDIVERS™ 2 - Upgrade to Super Citizen Edition
# 21                           Arms Trade Tycoon: Tanks
# 22                  Vampire: The Masquerade - Justice
# 24                                               CLeM
# 25                                    Shanghai Summer
# 26               Touhou Danmaku Kagura Phantasia Lost
# 27  KONOSUBA - God's Blessing on this Wonderful Wo...
# 28                                          WitchHand
# 29                                         SpellRogue
# 30                                     100 Ninja Cats
# 31                  And the Hero Was Never Seen Again
# 32                             Cats Hidden in Georgia
# 33                                     The Inquisitor
# 34                   Lysfanga: The Time Shift Warrior
# 35                                         News Tower
# 36                                       Fight Crab 2
# 37                                             Ultros
# 38                                     Lords of Exile
# 39                     Arzette: The Jewel of Faramore
# 40                       Deep Rock Galactic: Survivor
# 41                                 Islands of Insight
# 42                      Banishers: Ghosts of New Eden
# 43                        GUNVOLT RECORDS Cychronicle
# 44   Tomb Raider I-III Remastered Starring Lara Croft
# 45                                    Solium Infernum
# 46                                           Helskate
# 47                                   Goat Simulator 3
# 48                           Level Unknown: Backrooms
# 52                                           Colonize
#
#                                           description  price  salePercentage  \
# 20                                        Desconocida  59.99           -40.0
# 21  Arms Trade Tycoon: Tanks is a unique combinati...  17.15           -40.0
# 22  Become a vampire. Strike from the darkness and...  17.15           -40.0
# 24  CLeM is a narrative-driven puzzle adventure ga...  17.15           -40.0
# 25  Shanghai Summer is an adventure game set in th...  17.15           -40.0
# 26  A rhythm game in which players can play popula...  17.15           -40.0
# 27  It's time for a Visual Novel Quest with a twis...  17.15           -40.0
# 28  You're a witch, leading your coven into new, u...  17.15           -40.0
# 29  SpellRogue is a turn-based, deckbuilding rogue...  17.15           -40.0
# 30  100 Ninja Cats - Join the cutest adventure in ...  17.15           -40.0
# 31  The Demon King lies defeated at the Hero's han...  17.15           -40.0
# 32  Find and discover 100 cute cats hidden across ...  17.15           -40.0
# 33  Jesus did not die on the cross, but came down ...  17.15           -40.0
# 34  Your Kingdom’s fate relies on you… you… and yo...  17.15           -40.0
# 35  Develop your newspaper and become New York’s n...  17.15           -40.0
# 36  Flip your opponents on their backs in this cru...  17.15           -40.0
# 37  ULTROS is a psychedelic metroidvania where you...  22.49           -10.0
# 38  Embark on a quest for revenge in Lords of Exil...  17.15           -40.0
# 39  A NEW interactive animated adventure! In this ...  17.15           -40.0
# 40  Deep Rock Galactic: Survivor is a single playe...  17.15           -40.0
# 41  Islands of Insight is a sublime shared-world p...  17.15           -40.0
# 42  Hunt ghosts as two memorable characters in a s...  49.99           -40.0
# 43  A new rhythm music game starring the songstres...  17.15           -40.0
# 44  Play the original three Tomb Raider adventures...  26.99           -10.0
# 45  Take the Infernal Throne in this hellish turn-...  17.15           -40.0
# 46  Helskate is a skateboarding action roguelite. ...  17.15           -40.0
# 47  Pilgor's baaack! Gather your herd and venture ...  17.15           -40.0
# 48  Embark on a chilling journey into the unknown ...  17.15           -40.0
# 52  Colonize is a combination of survival game and...  17.15           -40.0
#
#    recentReviews allReviews
# 20   Desconocida        NaN
# 21   Desconocida        NaN
# 22   Desconocida        NaN
# 24   Desconocida        NaN
# 25   Desconocida        NaN
# 26   Desconocida        NaN
# 27   Desconocida        NaN
# 28   Desconocida        NaN
# 29   Desconocida        NaN
# 30   Desconocida        NaN
# 31   Desconocida        NaN
# 32   Desconocida        NaN
# 33   Desconocida        NaN
# 34   Desconocida        NaN
# 35   Desconocida        NaN
# 36   Desconocida        NaN
# 37   Desconocida        NaN
# 38   Desconocida        NaN
# 39   Desconocida        NaN
# 40   Desconocida        NaN
# 41   Desconocida        NaN
# 42   Desconocida        NaN
# 43   Desconocida        NaN
# 44   Desconocida        NaN
# 45   Desconocida        NaN
# 46   Desconocida        NaN
# 47   Desconocida        NaN
# 48   Desconocida        NaN
# 52   Desconocida        NaN

# %%
df["allReviews"] = df["allReviews"].fillna("Desconocida")

df[df["allReviews"] == "Desconocida"]
# Out:
#                                                 title  \
# 20   HELLDIVERS™ 2 - Upgrade to Super Citizen Edition
# 21                           Arms Trade Tycoon: Tanks
# 22                  Vampire: The Masquerade - Justice
# 24                                               CLeM
# 25                                    Shanghai Summer
# 26               Touhou Danmaku Kagura Phantasia Lost
# 27  KONOSUBA - God's Blessing on this Wonderful Wo...
# 28                                          WitchHand
# 29                                         SpellRogue
# 30                                     100 Ninja Cats
# 31                  And the Hero Was Never Seen Again
# 32                             Cats Hidden in Georgia
# 33                                     The Inquisitor
# 34                   Lysfanga: The Time Shift Warrior
# 35                                         News Tower
# 36                                       Fight Crab 2
# 37                                             Ultros
# 38                                     Lords of Exile
# 39                     Arzette: The Jewel of Faramore
# 40                       Deep Rock Galactic: Survivor
# 41                                 Islands of Insight
# 42                      Banishers: Ghosts of New Eden
# 43                        GUNVOLT RECORDS Cychronicle
# 44   Tomb Raider I-III Remastered Starring Lara Croft
# 45                                    Solium Infernum
# 46                                           Helskate
# 47                                   Goat Simulator 3
# 48                           Level Unknown: Backrooms
# 52                                           Colonize
#
#                                           description  price  salePercentage  \
# 20                                        Desconocida  59.99           -40.0
# 21  Arms Trade Tycoon: Tanks is a unique combinati...  17.15           -40.0
# 22  Become a vampire. Strike from the darkness and...  17.15           -40.0
# 24  CLeM is a narrative-driven puzzle adventure ga...  17.15           -40.0
# 25  Shanghai Summer is an adventure game set in th...  17.15           -40.0
# 26  A rhythm game in which players can play popula...  17.15           -40.0
# 27  It's time for a Visual Novel Quest with a twis...  17.15           -40.0
# 28  You're a witch, leading your coven into new, u...  17.15           -40.0
# 29  SpellRogue is a turn-based, deckbuilding rogue...  17.15           -40.0
# 30  100 Ninja Cats - Join the cutest adventure in ...  17.15           -40.0
# 31  The Demon King lies defeated at the Hero's han...  17.15           -40.0
# 32  Find and discover 100 cute cats hidden across ...  17.15           -40.0
# 33  Jesus did not die on the cross, but came down ...  17.15           -40.0
# 34  Your Kingdom’s fate relies on you… you… and yo...  17.15           -40.0
# 35  Develop your newspaper and become New York’s n...  17.15           -40.0
# 36  Flip your opponents on their backs in this cru...  17.15           -40.0
# 37  ULTROS is a psychedelic metroidvania where you...  22.49           -10.0
# 38  Embark on a quest for revenge in Lords of Exil...  17.15           -40.0
# 39  A NEW interactive animated adventure! In this ...  17.15           -40.0
# 40  Deep Rock Galactic: Survivor is a single playe...  17.15           -40.0
# 41  Islands of Insight is a sublime shared-world p...  17.15           -40.0
# 42  Hunt ghosts as two memorable characters in a s...  49.99           -40.0
# 43  A new rhythm music game starring the songstres...  17.15           -40.0
# 44  Play the original three Tomb Raider adventures...  26.99           -10.0
# 45  Take the Infernal Throne in this hellish turn-...  17.15           -40.0
# 46  Helskate is a skateboarding action roguelite. ...  17.15           -40.0
# 47  Pilgor's baaack! Gather your herd and venture ...  17.15           -40.0
# 48  Embark on a chilling journey into the unknown ...  17.15           -40.0
# 52  Colonize is a combination of survival game and...  17.15           -40.0
#
#    recentReviews   allReviews
# 20   Desconocida  Desconocida
# 21   Desconocida  Desconocida
# 22   Desconocida  Desconocida
# 24   Desconocida  Desconocida
# 25   Desconocida  Desconocida
# 26   Desconocida  Desconocida
# 27   Desconocida  Desconocida
# 28   Desconocida  Desconocida
# 29   Desconocida  Desconocida
# 30   Desconocida  Desconocida
# 31   Desconocida  Desconocida
# 32   Desconocida  Desconocida
# 33   Desconocida  Desconocida
# 34   Desconocida  Desconocida
# 35   Desconocida  Desconocida
# 36   Desconocida  Desconocida
# 37   Desconocida  Desconocida
# 38   Desconocida  Desconocida
# 39   Desconocida  Desconocida
# 40   Desconocida  Desconocida
# 41   Desconocida  Desconocida
# 42   Desconocida  Desconocida
# 43   Desconocida  Desconocida
# 44   Desconocida  Desconocida
# 45   Desconocida  Desconocida
# 46   Desconocida  Desconocida
# 47   Desconocida  Desconocida
# 48   Desconocida  Desconocida
# 52   Desconocida  Desconocida

# %% [markdown]
# Resultado final del manejo de datos nulos:

# %%
df.isnull().sum()
# Out:
# title             0
# description       0
# price             0
# salePercentage    0
# recentReviews     0
# allReviews        0
# dtype: int64

# %% [markdown]
# ##### Comprueba si existen registros duplicados, y si existen eliminalos

# %%
# Detectamos todos los registros duplicados por el nombre del juego

duplicados = df[df.duplicated(subset=["title"], keep=False)]

nombres_duplicados = duplicados["title"].unique()

print(nombres_duplicados)
# Out:
# ['Ori and the Will of the Wisps'
#  'Flashing Lights - Police, Firefighting, Emergency Services (EMS) Simulator'
#  'Thronefall'
#  'DRAGON QUEST® XI S: Echoes of an Elusive Age™ - Definitive Edition'
#  'Bendy and the Dark Revival' 'CARRION' 'Thymesia' 'Ready or Not'
#  'FINAL FANTASY VII REMAKE INTERGRADE' 'Hogwarts Legacy'
#  'Dead by Daylight']

# %%
# Eliminamos los registros duplicados

df = df.drop_duplicates()

# %% [markdown]
# ##### Exportamos el DataFrame limpio a un fichero externo

# %%
df.to_csv('./data/cleaned_steam_data.csv')

# %% [markdown]
# ---
# #### 3. Analisis de datos
# ---

# %% [markdown]
# ##### Carga del nuevo CSV

# %%
clean_df = pd.read_csv('./data/cleaned_steam_data.csv')

# %% [markdown]
# ##### Identifica el juego más caro

# %%
precio_mas_alto = clean_df["price"].max()

clean_df[clean_df["price"] == precio_mas_alto][['title', 'price']]
# Out:
#                                                title  price
# 20  HELLDIVERS™ 2 - Upgrade to Super Citizen Edition  59.99

# %% [markdown]
# ##### Identifica el juego más barato

# %%
precio_mas_bajo = clean_df["price"].min()

clean_df[clean_df["price"] == precio_mas_bajo][["title", "price"]]
# Out:
#                                        title  price
# 67  Star Wars: Battlefront 2 (Classic, 2005)   3.49

# %% [markdown]
# ##### Identifica el juego con el mayor porcentaje de descuento.

# %%
# Obtenemos el valor más bajo de la columna 'salesPercentage'
descuento_maximo = clean_df["salePercentage"].min()

# Mostramos el regitro que tenga el campo 'salesPercetage' igual al valor de 'max_discount'
clean_df[clean_df["salePercentage"] == descuento_maximo][['title', 'salePercentage']]
# Out:
#                         title  salePercentage
# 6  Bendy and the Dark Revival           -80.0

# %% [markdown]
# ##### Identifica el juego con el precio más alto y el más bajo, luego calcula la diferencia en el porcentaje de descuento entre ellos

# %%
# Obtenemos el precio del juego más caro y más barato

precio_mas_caro = clean_df["price"].max()

precio_mas_barato = clean_df["price"].min()

# En base a los precios, obtenemos los datos del juego más caro y el juego más barato, importante eliminar el index con 'reset_index' para que solo obtengamos el dato

juego_mas_caro = clean_df[clean_df["price"] == precio_mas_caro].reset_index(drop=True)

juego_mas_barato = clean_df[clean_df["price"] == precio_mas_barato].reset_index(
    drop=True
)

# Al tener todos los datos de ambos juegos podemos obtener la diferencia de ambos con respecto al precio

diferencia_entre_juegos = juego_mas_caro["price"] - juego_mas_barato["price"]

diferencia_entre_juegos
# Out:
# 0    56.5
# Name: price, dtype: float64

# %% [markdown]
# ##### Identifica el total de juegos con valoraciones positivas

# %%
# Valoraciones positivas incluye: Overwhelmingly Positive, Very Positive, Mostly Positive

lista = ['Overwhelmingly Positive', 'Very Positive', 'Mostly Positive']

juegos_con_reviews_positivas = df[df["recentReviews"].isin(lista)]['title'].count()

print(f"Existen un total de {juegos_con_reviews_positivas} juegos con valoraciones positivas")
# Out:
# Existen un total de 44 juegos con valoraciones positivas

# %% [markdown]
# ##### Crea una nueva columna llamada discountedPrice y usa la siguiente formula: __discountedPrice=price×(1−salePercentage/100)__

# %%
clean_df["discountPrice"] = clean_df["price"] * (1 - clean_df["salePercentage"] / 100)

clean_df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0                      Ori and the Will of the Wisps
# 1           1  Flashing Lights - Police, Firefighting, Emerge...
# 2           2                                         Thronefall
# 3           3  DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...
# 4           4                                            UNDYING
#
#                                          description  price  salePercentage  \
# 0  Play the critically acclaimed masterpiece. Emb...   9.89           -67.0
# 1  Play solo or in up to 10-player multiplayer co...   8.49           -66.0
# 2  A minimalist game about building and defending...   5.24           -25.0
# 3  The Definitive Edition includes the critically...  23.99           -40.0
# 4  As Anling’s zombie infection sets in, her days...  13.99           -30.0
#
#              recentReviews               allReviews  discountPrice
# 0  Overwhelmingly Positive  Overwhelmingly Positive        16.5163
# 1            Very Positive            Very Positive        14.0934
# 2  Overwhelmingly Positive  Overwhelmingly Positive         6.5500
# 3            Very Positive            Very Positive        33.5860
# 4          Mostly Positive          Mostly Positive        18.1870

# %% [markdown]
# ##### Agrupa los datos por recentReviews y calcula el precio promedio (price) y el precio promedio después del descuento (discountedPrice).

# %%
df_agrupado = clean_df.groupby("recentReviews").agg(
    {"price": "mean", "discountPrice": "mean"}
)

df_agrupado
# Out:
#                              price  discountPrice
# recentReviews
# Desconocida              20.283103      27.884483
# Mixed                    23.990000      38.384000
# Mostly Negative          33.000000      55.110000
# Mostly Positive          21.084286      30.436643
# Overwhelmingly Positive  10.420000      16.163460
# Very Positive            20.105625      28.695119

# %% [markdown]
# ##### Ordena los juegos por precio de mayor a menor, muestras los 3 más caros y los 3 más baratos y despues unificalos

# %%
# Ordenamos el DataFrame

df_ordenado_por_precio = clean_df.sort_values(by='price', ascending=False)

# %%
# Seleccionamos los 3 más caros

juegos_mas_caros = df_ordenado_por_precio.head(3)

juegos_mas_caros
# Out:
#     Unnamed: 0                                             title  \
# 20          20  HELLDIVERS™ 2 - Upgrade to Super Citizen Edition
# 42          42                     Banishers: Ghosts of New Eden
# 19          19                                    Hell Let Loose
#
#                                           description  price  salePercentage  \
# 20                                        Desconocida  59.99           -40.0
# 42  Hunt ghosts as two memorable characters in a s...  49.99           -40.0
# 19  Join the ever expanding experience of Hell Let...  42.24           -35.0
#
#     recentReviews     allReviews  discountPrice
# 20    Desconocida    Desconocida         83.986
# 42    Desconocida    Desconocida         69.986
# 19  Very Positive  Very Positive         57.024

# %%
# Seleccionamos los 3 más baratos

juegos_mas_baratos = df_ordenado_por_precio.tail(3)

juegos_mas_baratos
# Out:
#     Unnamed: 0                                     title  \
# 2            2                                Thronefall
# 71          80      LEGO® Star Wars™ - The Complete Saga
# 67          75  Star Wars: Battlefront 2 (Classic, 2005)
#
#                                           description  price  salePercentage  \
# 2   A minimalist game about building and defending...   5.24           -25.0
# 71  Kick Some Brick in I through VI! Play through ...   4.99           -75.0
# 67  Join the rise of Darth Vader’s elite 501st Leg...   3.49           -65.0
#
#               recentReviews               allReviews  discountPrice
# 2   Overwhelmingly Positive  Overwhelmingly Positive         6.5500
# 71  Overwhelmingly Positive  Overwhelmingly Positive         8.7325
# 67            Very Positive            Very Positive         5.7585

# %%
# Unificamos los 3 juegos más caros y más baratos en un DataFrame

lista_definitiva = pd.concat([juegos_mas_caros, juegos_mas_baratos], axis=0)

lista_definitiva
# Out:
#     Unnamed: 0                                             title  \
# 20          20  HELLDIVERS™ 2 - Upgrade to Super Citizen Edition
# 42          42                     Banishers: Ghosts of New Eden
# 19          19                                    Hell Let Loose
# 2            2                                        Thronefall
# 71          80              LEGO® Star Wars™ - The Complete Saga
# 67          75          Star Wars: Battlefront 2 (Classic, 2005)
#
#                                           description  price  salePercentage  \
# 20                                        Desconocida  59.99           -40.0
# 42  Hunt ghosts as two memorable characters in a s...  49.99           -40.0
# 19  Join the ever expanding experience of Hell Let...  42.24           -35.0
# 2   A minimalist game about building and defending...   5.24           -25.0
# 71  Kick Some Brick in I through VI! Play through ...   4.99           -75.0
# 67  Join the rise of Darth Vader’s elite 501st Leg...   3.49           -65.0
#
#               recentReviews               allReviews  discountPrice
# 20              Desconocida              Desconocida        83.9860
# 42              Desconocida              Desconocida        69.9860
# 19            Very Positive            Very Positive        57.0240
# 2   Overwhelmingly Positive  Overwhelmingly Positive         6.5500
# 71  Overwhelmingly Positive  Overwhelmingly Positive         8.7325
# 67            Very Positive            Very Positive         5.7585
